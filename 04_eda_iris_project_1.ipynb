# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/Admin/Desktop/ecoders_ds_11am/all_datasets/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width variety
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'variety'],
#       dtype='object')

# %%
df["variety"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: variety, Length: 150, dtype: object

# %%
df["variety"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: variety, dtype: int64

# %%
df[['petal_length', 'petal_width']]
# Out:
#      petal_length  petal_width
# 0             1.4          0.2
# 1             1.4          0.2
# 2             1.3          0.2
# 3             1.5          0.2
# 4             1.4          0.2
# ..            ...          ...
# 145           5.2          2.3
# 146           5.0          1.9
# 147           5.2          2.0
# 148           5.4          2.3
# 149           5.1          1.8
#
# [150 rows x 2 columns]

# %%
onlysetosaflower = df[df["variety"] == "setosa"]
onlysetosaflower
onlysetosaflower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
onlyvirginicaflower = df[df["variety"] == "virginica"]
onlyvirginicaflower
onlyvirginicaflower.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica

# %%
onlyversicolorflower = df[df["variety"] == "versicolor"]
onlyversicolorflower
onlyversicolorflower.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     variety
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor

# %%
df.plot(kind = "scatter",  x = "sepal_length" , y = "sepal_width")
plt.show()

# %%
df.plot(kind = "scatter",  x = "petal_length" , y = "petal_width")
plt.show()

# %%
import seaborn as sns

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df, hue = "variety", size = 5).map(plt.scatter, "sepal_length", "sepal_width").add_legend()
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df, hue = "variety", size = 5).map(plt.scatter, "petal_length", "petal_width").add_legend()
plt.show()

# %%
sns.set_style("whitegrid")
sns.pairplot(df, hue = "variety", size = 5).add_legend()
plt.show()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df, hue = "variety", size = 5).map(plt.scatter, "petal_length", "petal_width").add_legend()
plt.show()

# %% [markdown]
# # Conclution:

# %% [markdown]
# 1. According to the pair plot, it is concluded that Petal length and petal width is the most importat features to identify
# flower types.
#
# Petal length 0-2 & petal width 0-0.7 => Setosa
# Petal length 3-5.2 & petal width 1-1.7 => Versicolor
# Petal length less than 5.2 & petal width is greater than 1.7 => Verginica
#
# 2. By the plotsSetosa can be easily identified (linearly sepratable), verginica and versicolor have some overlap
# (almost linearly separatble)
#
# 3. We can find lines and by using if-else conditions we can build a simple model to classify flower type.
